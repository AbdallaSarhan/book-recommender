# %%
import pandas as pd

books = pd.read_csv("books_cleaned_with_categories.csv")
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780002261982  0002261987
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# ...             ...         ...
# 5194  9788172235222  8172235224
# 5195  9788173031014  8173031010
# 5196  9788179921623  817992162X
# 5197  9788185300535  8185300534
# 5198  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                          Spider's Web
# 3                                        Rage of angels
# 4                                        The Four Loves
# ...                                                 ...
# 5194                                  Mistaken Identity
# 5195                                Journey to the East
# 5196  The Monk Who Sold His Ferrari: A Fable About F...
# 5197                                          I Am that
# 5198                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                  Charles Osborne;Agatha Christie
# 3                                   Sidney Sheldon
# 4                              Clive Staples Lewis
# ...                                            ...
# 5194                              Nayantara Sahgal
# 5195                                 Hermann Hesse
# 5196                                  Robin Sharma
# 5197  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5198                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2     Detective and mystery stories
# 3                           Fiction
# 4                    Christian life
# ...                             ...
# 5194        Indic fiction (English)
# 5195              Adventure stories
# 5196               Health & Fitness
# 5197                     Philosophy
# 5198                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=gA5GP...
# 3     http://books.google.com/books/content?id=FKo2T...
# 4     http://books.google.com/books/content?id=XhQ5X...
# ...                                                 ...
# 5194  http://books.google.com/books/content?id=q-tKP...
# 5195  http://books.google.com/books/content?id=rq6JP...
# 5196  http://books.google.com/books/content?id=c_7mf...
# 5197  http://books.google.com/books/content?id=Fv_JP...
# 5198  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 3     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4     Lewis' work on the nature of love divides love...          2002.0
# ...                                                 ...             ...
# 5194  On A Train Journey Home To North India After L...          2003.0
# 5195  This book tells the tale of a man who goes on ...          2002.0
# 5196  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5197  This collection of the timeless teachings of o...          1999.0
# 5198  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.83      241.0         5164.0
# 3               3.93      512.0        29532.0
# 4               4.15      170.0        33684.0
# ...              ...        ...            ...
# 5194            2.93      324.0            0.0
# 5195            3.70      175.0           24.0
# 5196            3.82      198.0         1568.0
# 5197            4.51      531.0          104.0
# 5198            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                  Spider's Web:A Novel
# 2                                  Spider's Web:A Novel
# 3                                        Rage of angels
# 4                                        The Four Loves
# ...                                                 ...
# 5194                                  Mistaken Identity
# 5195                                Journey to the East
# 5196  The Monk Who Sold His Ferrari: A Fable About F...
# 5197      I Am that:Talks with Sri Nisargadatta Maharaj
# 5198                           The Berlin Phenomenology
#
#                                      tagged_description simple categories  \
# 0     9780002005883:A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982:A new 'Christie for Christmas' -...               NaN
# 2     9780002261982:A new 'Christie for Christmas' -...               NaN
# 3     9780006178736:A memorable, mesmerizing heroine...           Fiction
# 4     9780006280897:Lewis' work on the nature of lov...               NaN
# ...                                                 ...               ...
# 5194  9788172235222:On A Train Journey Home To North...               NaN
# 5195  9788173031014:This book tells the tale of a ma...               NaN
# 5196  9788179921623:Wisdom to Create a Life of Passi...               NaN
# 5197  9788185300535:This collection of the timeless ...        Nonfiction
# 5198  9789027712059:Since the three volume edition o...        Nonfiction
#
#      simple_categories
# 0              Fiction
# 1              Fiction
# 2              Fiction
# 3              Fiction
# 4           Nonfiction
# ...                ...
# 5194           Fiction
# 5195        Nonfiction
# 5196           Fiction
# 5197        Nonfiction
# 5198        Nonfiction
#
# [5199 rows x 15 columns]

# %%
from transformers import pipeline

classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", top_k = None)
classifier("I love this book!")
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at j-hartmann/emotion-english-distilroberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# Device set to use 0
# [[{'label': 'joy', 'score': 0.9771486520767212},
#   {'label': 'surprise', 'score': 0.010831067338585854},
#   {'label': 'neutral', 'score': 0.00458167539909482},
#   {'label': 'anger', 'score': 0.0037370086647570133},
#   {'label': 'sadness', 'score': 0.002046085661277175},
#   {'label': 'disgust', 'score': 0.0012559974566102028},
#   {'label': 'fear', 'score': 0.00039950647624209523}]]

# %%
books['description'][0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.'

# %%
classifier(books['description'][0])
# Out:
# [[{'label': 'fear', 'score': 0.6548411846160889},
#   {'label': 'neutral', 'score': 0.16985204815864563},
#   {'label': 'sadness', 'score': 0.11640877276659012},
#   {'label': 'surprise', 'score': 0.02070068009197712},
#   {'label': 'disgust', 'score': 0.019100705161690712},
#   {'label': 'joy', 'score': 0.015161309391260147},
#   {'label': 'anger', 'score': 0.003935149870812893}]]

# %%
sentences = books['description'][0].split(".")
predictions = classifier(sentences)

# %%
sentences[0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives'

# %%
predictions[0]
# Out:
# [{'label': 'surprise', 'score': 0.7296028733253479},
#  {'label': 'neutral', 'score': 0.14038558304309845},
#  {'label': 'fear', 'score': 0.06816215068101883},
#  {'label': 'joy', 'score': 0.04794241115450859},
#  {'label': 'anger', 'score': 0.009156353771686554},
#  {'label': 'disgust', 'score': 0.0026284768246114254},
#  {'label': 'sadness', 'score': 0.002122160978615284}]

# %%
sentences[3]
# Out:
# ' Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist'

# %%
predictions[3]
# Out:
# [{'label': 'fear', 'score': 0.9281682968139648},
#  {'label': 'anger', 'score': 0.03219075873494148},
#  {'label': 'neutral', 'score': 0.012808691710233688},
#  {'label': 'sadness', 'score': 0.008756875991821289},
#  {'label': 'surprise', 'score': 0.008597909472882748},
#  {'label': 'disgust', 'score': 0.008431827649474144},
#  {'label': 'joy', 'score': 0.0010455823503434658}]

# %%
sorted(predictions[0], key=lambda x: x['label'])
# Out:
# [{'label': 'anger', 'score': 0.009156353771686554},
#  {'label': 'disgust', 'score': 0.0026284768246114254},
#  {'label': 'fear', 'score': 0.06816215068101883},
#  {'label': 'joy', 'score': 0.04794241115450859},
#  {'label': 'neutral', 'score': 0.14038558304309845},
#  {'label': 'sadness', 'score': 0.002122160978615284},
#  {'label': 'surprise', 'score': 0.7296028733253479}]

# %%
import numpy as np

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x: x['label'])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_predictions[index]['score'])
    return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books['isbn13'][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])

# %%
emotion_scores
# Out:
# {'anger': [0.06413357704877853,
#   0.6126188039779663,
#   0.6126188039779663,
#   0.06413357704877853,
#   0.35148385167121887,
#   0.35148385167121887,
#   0.08141231536865234,
#   0.23222453892230988,
#   0.5381845831871033,
#   0.06413357704877853],
#  'disgust': [0.27359193563461304,
#   0.3482849895954132,
#   0.3482849895954132,
#   0.10400662571191788,
#   0.15072239935398102,
#   0.15072239935398102,
#   0.18449510633945465,
#   0.7271750569343567,
#   0.15585483610630035,
#   0.10400662571191788],
#  'fear': [0.9281682968139648,
#   0.9425276517868042,
#   0.9425276517868042,
#   0.9723208546638489,
#   0.3607066571712494,
#   0.3607066571712494,
#   0.09504330903291702,
#   0.0513627715408802,
#   0.7474281787872314,
#   0.4044972062110901],
#  'joy': [0.9327978491783142,
#   0.704421877861023,
#   0.704421877861023,
#   0.7672375440597534,
#   0.25188082456588745,
#   0.25188082456588745,
#   0.0405644029378891,
#   0.04337587580084801,
#   0.8725654482841492,
#   0.0405644029378891],
#  'sadness': [0.646216094493866,
#   0.887939453125,
#   0.887939453125,
#   0.5494769811630249,
#   0.7326854467391968,
#   0.7326854467391968,
#   0.8843894600868225,
#   0.6213928461074829,
#   0.7121944427490234,
#   0.5494769811630249],
#  'surprise': [0.9671575427055359,
#   0.11169016361236572,
#   0.11169016361236572,
#   0.11169016361236572,
#   0.11169016361236572,
#   0.11169016361236572,
#   0.4758811891078949,
#   0.11169016361236572,
#   0.4080003798007965,
#   0.8202818036079407],
#  'neutral': [0.7296028733253479,
#   0.25254493951797485,
#   0.25254493951797485,
#   0.07876548171043396,
#   0.07876548171043396,
#   0.07876548171043396,
#   0.07876548171043396,
#   0.2719026207923889,
#   0.07876548171043396,
#   0.23448702692985535]}

# %%
from tqdm import tqdm

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books['isbn13'][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 5199/5199 [16:22<00:00,  5.29it/s]

# %%
emotions_df = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn

# %%
emotions_df
# Out:
#          anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0     0.064134  0.273592  0.928168  0.932798  0.646216  0.967158  0.729603
# 1     0.612619  0.348285  0.942528  0.704422  0.887939  0.111690  0.252545
# 2     0.612619  0.348285  0.942528  0.704422  0.887939  0.111690  0.252545
# 3     0.064134  0.104007  0.972321  0.767238  0.549477  0.111690  0.078765
# 4     0.351484  0.150722  0.360707  0.251881  0.732685  0.111690  0.078765
# ...        ...       ...       ...       ...       ...       ...       ...
# 5194  0.148208  0.030643  0.919165  0.255170  0.853722  0.980877  0.030656
# 5195  0.064134  0.114383  0.051363  0.400263  0.883198  0.111690  0.227765
# 5196  0.009997  0.009929  0.339218  0.947779  0.375755  0.066685  0.057625
# 5197  0.064134  0.104007  0.459270  0.759456  0.951104  0.368111  0.078765
# 5198  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078765
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# 2     9780002261982
# 3     9780006178736
# 4     9780006280897
# ...             ...
# 5194  9788172235222
# 5195  9788173031014
# 5196  9788179921623
# 5197  9788185300535
# 5198  9789027712059
#
# [5199 rows x 8 columns]

# %%
books = pd.merge(books, emotions_df, on = "isbn13")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780002261982  0002261987
# 3     9780002261982  0002261987
# 4     9780002261982  0002261987
# ...             ...         ...
# 5198  9788172235222  8172235224
# 5199  9788173031014  8173031010
# 5200  9788179921623  817992162X
# 5201  9788185300535  8185300534
# 5202  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                          Spider's Web
# 3                                          Spider's Web
# 4                                          Spider's Web
# ...                                                 ...
# 5198                                  Mistaken Identity
# 5199                                Journey to the East
# 5200  The Monk Who Sold His Ferrari: A Fable About F...
# 5201                                          I Am that
# 5202                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                  Charles Osborne;Agatha Christie
# 3                  Charles Osborne;Agatha Christie
# 4                  Charles Osborne;Agatha Christie
# ...                                            ...
# 5198                              Nayantara Sahgal
# 5199                                 Hermann Hesse
# 5200                                  Robin Sharma
# 5201  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5202                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2     Detective and mystery stories
# 3     Detective and mystery stories
# 4     Detective and mystery stories
# ...                             ...
# 5198        Indic fiction (English)
# 5199              Adventure stories
# 5200               Health & Fitness
# 5201                     Philosophy
# 5202                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=gA5GP...
# 3     http://books.google.com/books/content?id=gA5GP...
# 4     http://books.google.com/books/content?id=gA5GP...
# ...                                                 ...
# 5198  http://books.google.com/books/content?id=q-tKP...
# 5199  http://books.google.com/books/content?id=rq6JP...
# 5200  http://books.google.com/books/content?id=c_7mf...
# 5201  http://books.google.com/books/content?id=Fv_JP...
# 5202  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 3     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 4     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# ...                                                 ...             ...
# 5198  On A Train Journey Home To North India After L...          2003.0
# 5199  This book tells the tale of a man who goes on ...          2002.0
# 5200  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5201  This collection of the timeless teachings of o...          1999.0
# 5202  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.83      241.0  ...
# 2               3.83      241.0  ...
# 3               3.83      241.0  ...
# 4               3.83      241.0  ...
# ...              ...        ...  ...
# 5198            2.93      324.0  ...
# 5199            3.70      175.0  ...
# 5200            3.82      198.0  ...
# 5201            4.51      531.0  ...
# 5202            0.00      210.0  ...
#
#                                      tagged_description simple categories  \
# 0     9780002005883:A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982:A new 'Christie for Christmas' -...               NaN
# 2     9780002261982:A new 'Christie for Christmas' -...               NaN
# 3     9780002261982:A new 'Christie for Christmas' -...               NaN
# 4     9780002261982:A new 'Christie for Christmas' -...               NaN
# ...                                                 ...               ...
# 5198  9788172235222:On A Train Journey Home To North...               NaN
# 5199  9788173031014:This book tells the tale of a ma...               NaN
# 5200  9788179921623:Wisdom to Create a Life of Passi...               NaN
# 5201  9788185300535:This collection of the timeless ...        Nonfiction
# 5202  9789027712059:Since the three volume edition o...        Nonfiction
#
#      simple_categories     anger   disgust      fear       joy   sadness  \
# 0              Fiction  0.064134  0.273592  0.928168  0.932798  0.646216
# 1              Fiction  0.612619  0.348285  0.942528  0.704422  0.887939
# 2              Fiction  0.612619  0.348285  0.942528  0.704422  0.887939
# 3              Fiction  0.612619  0.348285  0.942528  0.704422  0.887939
# 4              Fiction  0.612619  0.348285  0.942528  0.704422  0.887939
# ...                ...       ...       ...       ...       ...       ...
# 5198           Fiction  0.148208  0.030643  0.919165  0.255170  0.853722
# 5199        Nonfiction  0.064134  0.114383  0.051363  0.400263  0.883198
# 5200           Fiction  0.009997  0.009929  0.339218  0.947779  0.375755
# 5201        Nonfiction  0.064134  0.104007  0.459270  0.759456  0.951104
# 5202        Nonfiction  0.064134  0.104007  0.051363  0.958549  0.915193
#
#       surprise   neutral
# 0     0.967158  0.729603
# 1     0.111690  0.252545
# 2     0.111690  0.252545
# 3     0.111690  0.252545
# 4     0.111690  0.252545
# ...        ...       ...
# 5198  0.980877  0.030656
# 5199  0.111690  0.227765
# 5200  0.066685  0.057625
# 5201  0.368111  0.078765
# 5202  0.111690  0.078765
#
# [5203 rows x 22 columns]

# %%
books.to_csv("books_with_emotions.csv", index=False)
